// %% [markdown]
// # Simple Hello World

// %%
String message = "Hello";

message + " World !"
// Out:
// Hello World !

// %% [markdown]
// # Atelier 2 - lancé de dé

// %%
System.out.println("Bonjour les MITD !");
// Out:
// Bonjour les MITD !

// %% [markdown]
// ## Etape 1
