// %% [markdown]
// # Simple Hello World

// %%
String message = "Hello";

message + " World !"
// Out:
// Hello World !

// %% [markdown]
// # Atelier 2 - lancé de dé

// %%
System.out.println("Bonjour les MITD !");
// Out:
// Bonjour les MITD !

// %% [markdown]
// ## Etape 1

// %%
import java.util.Random;

// Étape 1 - Tirage aléatoire
Random hasard = new Random();
int alea = hasard.nextInt(6) + 1;

System.out.println("Valeur du dé : " + alea);
System.out.println();

// Étape 2 - Affichage du dé
char u, d, q, s;

// u vaut '*' quand la valeur du dé est impaire
if (alea % 2 == 1) {
    u = '*';
} else {
    u = ' ';
}

// d vaut '*' quand la valeur du dé vaut ou dépasse 2
if (alea >= 2) {
    d = '*';
} else {
    d = ' ';
}

// q vaut '*' quand la valeur du dé vaut ou dépasse 4
if (alea >= 4) {
    q = '*';
} else {
    q = ' ';
}

// s vaut '*' quand la valeur du dé vaut ou dépasse 2
if (alea >= 2) {
    s = '*';
} else {
    s = ' ';
}

// Affichage du dé selon le schéma
System.out.println(q + "   " + d);
System.out.println(s + " " + u + " " + s);
System.out.println(d + "   " + q);
// Out:
// Valeur du dé : 4
//
// *   *
// *   *
// *   *
